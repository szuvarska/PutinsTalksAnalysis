# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import pipeline
from tqdm import tqdm

# %%
putins_talks = pd.read_csv("data/putins_talks_prepared.csv")
dates_tags = pd.read_csv("data/dates_tags.csv")

# %%
putins_talks
# Out:
#                      date persons  \
# 0     2012-05-07 12:20:00      []
# 1     2012-05-08 16:00:00      []
# 2     2012-05-09 11:00:00      []
# 3     2012-05-09 13:00:00      []
# 4     2012-05-10 14:00:00      []
# ...                   ...     ...
# 5074  2023-01-10 13:45:00      []
# 5075  2023-01-11 15:50:00      []
# 5076  2023-01-12 00:00:00      []
# 5077  2023-01-13 12:55:00      []
# 5078  2023-01-13 14:35:00      []
#
#                                   transcript_unfiltered  kremlin_id  \
# 0     The ceremony opened with the Russian State Fla...     15224.0
# 1     State Duma deputies approved Dmitry Medvedev a...     15266.0
# 2     More than 14,000 military servicemen took part...     15271.0
# 3     * * * President of Russia Vladimir Putin: Vete...     15272.0
# 4     Vladimir Putin thanked the members of the plan...     15282.0
# ...                                                 ...         ...
# 5074  President of Russia Vladimir Putin: Mr Shaskol...     70336.0
# 5075  The meeting was attended by Prime Minister Mik...     70338.0
# 5076  President of Russia Vladimir Putin: Comrade of...     70341.0
# 5077  President of Russia Vladimir Putin: Mr Khabiro...     70347.0
# 5078  Pavel Zarubin: Bashkortostan is my homeland. I...     70350.0
#
#                              place  \
# 0              The Kremlin, Moscow
# 1                           Moscow
# 2                           Moscow
# 3                              NaN
# 4                     Nizhny Tagil
# ...                            ...
# 5074           The Kremlin, Moscow
# 5075  Novo-Ogaryovo, Moscow Region
# 5076                           NaN
# 5077                           Ufa
# 5078                           Ufa
#
#                                                   title  \
# 0     Vladimir Putin inaugurated as President of Russia
# 1                            State Duma plenary session
# 2     Military parade celebrating the 67th anniversa...
# 3     Reception marking the 67th anniversary of vict...
# 4     Visit to Research and Production Corporation U...
# ...                                                 ...
# 5074  Meeting with Federal Anti-Monopoly Service Hea...
# 5075                    Meeting with Government members
# 5076  Congratulations on Prosecutor's Office Workers...
# 5077  Meeting with Head of Bashkortostan Radiy Khabirov
# 5078                     Comment for Rossiya TV channel
#
#                                                  teaser  \
# 0     The inauguration ceremony took place in the Gr...
# 1     Vladimir Putin presented the candidacy of Dmit...
# 2     Vladimir Putin attended the military parade on...
# 3     A reception marking the 67th anniversary of vi...
# 4     In Nizhny Tagil, Vladimir Putin visited Uralva...
# ...                                                 ...
# 5074  Vladimir Putin had a working meeting with Head...
# 5075  The President held a videoconference meeting w...
# 5076  The President congratulated current staff and ...
# 5077  The President had a meeting with Head of the R...
# 5078  Vladimir Putin gave a comment to Rossyia 1 TV ...
#
#                                                    tags  \
# 0                                                    []
# 1                                     ['Civil service']
# 2                                      ['Armed Forces']
# 3                                                    []
# 4                                           ['Regions']
# ...                                                 ...
# 5074                            ['Economy and finance']
# 5075  ['Construction industry', 'Economy and finance...
# 5076                            ['Fight against crime']
# 5077                                        ['Regions']
# 5078                               ['Media', 'Regions']
#
#                                     transcript_filtered  \
# 0     Citizens of Russia, friends, The inauguration ...
# 1     Mr Naryshkin, deputies of the Russian parliame...
# 2     Citizens of Russia! Veterans! Comrade soldiers...
# 3     Veterans, colleagues, friends! We all share th...
# 4     Good afternoon, I want to thank all of you for...
# ...                                                 ...
# 5074  Mr Shaskolsky, the Federal Anti-Monopoly Servi...
# 5075  Good afternoon, colleagues, We are holding the...
# 5076  Comrade officers, veterans, Congratulations on...
# 5077  Mr Khabirov, good afternoon. Let me start by s...
# 5078  Where were you born? And what a pleasure it wa...
#
#                                                wordlist  \
# 0     ['citizen', 'of', 'Russia', ',', 'friend', ','...
# 1     ['Mr', 'Naryshkin', ',', 'deputy', 'of', 'the'...
# 2     ['citizen', 'of', 'Russia', '!', 'veteran', '!...
# 3     ['veteran', ',', 'colleague', ',', 'friend', '...
# 4     ['good', 'afternoon', ',', 'I', 'want', 'to', ...
# ...                                                 ...
# 5074  ['Mr', 'Shaskolsky', ',', 'the', 'Federal', 'A...
# 5075  ['good', 'afternoon', ',', 'colleague', ',', '...
# 5076  ['comrade', 'officer', ',', 'veteran', ',', 'c...
# 5077  ['Mr', 'Khabirov', ',', 'good', 'afternoon', '...
# 5078  ['where', 'be', 'you', 'bear', '?', 'and', 'wh...
#
#                                           grouped_tages
# 0                                                    []
# 1                   ['State_Governance_Public_Service']
# 2                      ['Security_Defense_Enforcement']
# 3                                                    []
# 4                   ['State_Governance_Public_Service']
# ...                                                 ...
# 5074                   ['Macroeconomics_Fiscal_Policy']
# 5075  ['Infrastructure_Housing_Construction', 'Macro...
# 5076                   ['Security_Defense_Enforcement']
# 5077                ['State_Governance_Public_Service']
# 5078  ['Sport_Tourism_Media', 'State_Governance_Publ...
#
# [5079 rows x 11 columns]

# %%
dates_tags
# Out:
#                      date                                          tags
# 0     2012-05-08 16:00:00               State_Governance_Public_Service
# 1     2012-05-09 11:00:00                  Security_Defense_Enforcement
# 2     2012-05-10 14:00:00               State_Governance_Public_Service
# 3     2012-05-11 13:00:00                           Sport_Tourism_Media
# 4     2012-05-11 16:00:00  International_Relations_Global_Organizations
# ...                   ...                                           ...
# 6292  2023-01-11 15:50:00                         Social_Welfare_Health
# 6293  2023-01-12 00:00:00                  Security_Defense_Enforcement
# 6294  2023-01-13 12:55:00               State_Governance_Public_Service
# 6295  2023-01-13 14:35:00                           Sport_Tourism_Media
# 6296  2023-01-13 14:35:00               State_Governance_Public_Service
#
# [6297 rows x 2 columns]

# %%
#histogram of speech lengths
putins_talks['length'] = putins_talks['transcript_filtered'].apply(lambda x: len(str(x).split()))

# %%
# Calculate number of speeches per year
yearly_counts = pd.to_datetime(putins_talks['date']).dt.year.value_counts().sort_index()
#from 2012
yearly_counts = yearly_counts[yearly_counts.index >= 2012]

plt.figure(figsize=(10, 6))
yearly_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title("Number of Putin's Speeches per Year")
plt.xlabel("Year")
plt.ylabel("Number of Speeches")
plt.xticks(rotation=45)

# Add values on top of bars
for i, v in enumerate(yearly_counts):
    plt.text(i, v + 5, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### length of speeches analysis

# %%
#lenghts of speeches density estimaotr plot
plt.figure(figsize=(10, 6))
filtered_lengths = putins_talks[putins_talks['date'] > '2012-01-01']['length']


mean_len = filtered_lengths.mean()

filtered_lengths.plot(kind='density', color='blue', label='Length density')
filtered_lengths.plot(kind='hist', density=True, bins=300, alpha=0.3, label='Length counted')

plt.axvline(mean_len, color='red', linestyle='--', label=f'Mean: {mean_len:.2f}')
plt.title('Length of speeches')
plt.xlabel('Number of words')
plt.xlim(0, 3000)
plt.gca().get_yaxis().set_visible(False)
plt.legend()
plt.show()

# %%
# Konwersja daty i obliczenie średniej długości przemówień na rok
putins_talks['date'] = pd.to_datetime(putins_talks['date'])
yearly_mean_len = putins_talks.groupby(putins_talks['date'].dt.year)['length'].mean()

# Filtrowanie danych do roku 2022 włącznie
plt.figure(figsize=(12, 6))
yearly_mean_len.plot(kind='line', marker='o', linestyle='-', color='blue')
plt.title('Average speech length over the years')
plt.xlabel('Year')
plt.ylabel('Average number of words')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(yearly_mean_len.index, rotation=45)
plt.show()

# %% [markdown]
# ### tags heatmap over time

# %%
#make a heatmap of tags over time with normalized counts
heatmap_data = dates_tags.copy()
heatmap_data['year'] = pd.to_datetime(heatmap_data['date']).dt.year
heatmap_data = heatmap_data.groupby(['year', 'tags']).size().unstack(fill_value=0)
heatmap_data = heatmap_data.apply(lambda x: x / x.sum(), axis=1)
plt.figure(figsize=(12, 8))
plt.imshow(heatmap_data.T, aspect='auto', cmap='viridis', origin='lower')
plt.colorbar(label='Normalized Count')
plt.yticks(range(len(heatmap_data.columns)), heatmap_data.columns)
plt.xticks(range(len(heatmap_data.index)), heatmap_data.index, rotation=45)
plt.xlabel('Year')
plt.ylabel('Tags')
plt.title("Heatmap of Tags Over Time")
plt.show()
